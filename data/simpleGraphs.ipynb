# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("priceWithTwitterData.csv").set_index('Unnamed: 0')
data.head()
# Out:
#                     BTC         ETH        LTC  Volume_BTC  Volume_Eth  \
# Unnamed: 0
# 1502978403  4440.544599  309.515187  44.228847    0.076872   17.338063
# 1502982003  4456.327055  306.333310  44.273498    0.709464    2.999052
# 1502985603  4380.102847  304.438850  44.102044    0.014249    0.157371
# 1502989203  4307.458884  300.147892  43.651379    0.279529    0.025056
# 1502992803  4301.538030  302.484477  43.773482    3.000000    2.000000
#
#             Volume_LTC   Volume_XRP       XRP  retweets  favorites
# Unnamed: 0
# 1502978403    17.46300   618.441080  0.157946       NaN        NaN
# 1502982003     1.10825  4431.120239  0.158022    1133.0     1810.0
# 1502985603    17.64000   283.563000  0.156558     841.0     1037.0
# 1502989203    12.35630   546.636750  0.155399     589.0     1095.0
# 1502992803    22.88000  1202.999924  0.156780    1411.0     1600.0

# %%
plt.plot(data.index,data['ETH'])

# %%
plt.plot(data.index,data['BTC'])

# %%
plt.plot(data.index,data['retweets'])

# %%
plt.plot(data.index,data['favorites'])
